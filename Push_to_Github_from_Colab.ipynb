# %%
# create folder in your drive (For example Github)
# %cd /content/drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %%
# The required information is as follows:

# Username of your Github
username = input("Enter your Github")

# Password
password = input("Enter your Password")

# email
email = input("Enter your email")

# your repository name
repo= input("Enter your repository name")

# You should generate token from your github
token= input("Enter your token")

# %%
# You should generate token from your github
token= input("Enter your token")
# Out:
# Enter your token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

# %%
#token="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"
token="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"
username = "Imed-Ha"
password = "Ha1705%%"
repo = "How-to-push-to-Github-from-Google-Colab"
#repo = "Detection_Pneumonia_Diseases"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("Username:", username)
print("password:", password)
print("email:", email)
print("repository:", repo)
print("token:", token)

# %%
# configure global variables
# !git config --global user.email "imed-eddine.haouli@univ-annaba.org"
# !git config --global user.name "Imed-Ha"
# !git config --global user.password "Ha1705%%"

# %%
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.email=imed-eddine.haouli@univ-annaba.org
# user.name=Imed-Ha
# user.password=Ha1705%%

# %%
# clone your repository to the created folder
# !git clone https://{token}@github.com/{username}/{repo}.git
# Out:
# Cloning into 'How-to-push-to-Github-from-Google-Colab'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 18 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), 5.66 KiB | 39.00 KiB/s, done.

# %%
# !git clone https://github.com/Imed-Ha/How-to-push-to-Github-from-Google-Colab.git
# Out:
# Cloning into 'How-to-push-to-Github-from-Google-Colab'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 17 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), 5.09 KiB | 26.00 KiB/s, done.

# %%
# %cd {repo}
# Out:
# /content/drive/MyDrive/Github/How-to-push-to-Github-from-Google-Colab

# %%
# %ls
# Out:
# README.md

# %%
# create new file
! touch Push_to_Github_from_Google_Colab.ipynb

# %%
# excute python file
! python new_file1.py

# %%
# verify the status 
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	new_file1.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# adding all changes 
# !git add --all
# !git add -a

# %%
# verify the status again
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   new_file1.py

# %%
# commit changes 
# !git commit -m "adding file1"
# Out:
# [main 6740c2d] adding file1
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 new_file1.py

# %%
# verify the status again
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# url of the all distant depots 
# !git remote -v
# Out:
# origin	https://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@github.com/Imed-Ha/Detection_Pneumonia_Diseases.git (fetch)
# origin	https://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@github.com/Imed-Ha/Detection_Pneumonia_Diseases.git (push)

# %%
# push changes to main branch
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 275 bytes | 91.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Imed-Ha/Detection_Pneumonia_Diseases.git
#    04c9555..6740c2d  main -> main

# %%
# To remove repo
# !rm -rf /content/drive/MyDrive/Github/How-to-push-to-Github-from-Google-Colab
